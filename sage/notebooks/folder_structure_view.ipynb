# %%
# !pip3 install pandas

# %%
import pandas as pd
import os
import glob
from pathlib import Path

# %%
pd.set_option('display.max_colwidth',0)

# %%
# path = "/Users/myplayhouse/Downloads/mattobra_stickers"
# path = "/Users/myplayhouse/Downloads/mattobra_maxine_attobrah_DIAMLkaggle"
# path = "/Users/myplayhouse/Downloads/archive(13)"
path = "../"

# %%
def get_folder_overview(path:str):
    sub_folder_names = []
    file_names = []
    file_sizes = []
    file_extenstions = []
    num_files_folder = []
    folder_paths = []
    is_folder = []
    depth_count = []

    files = glob.glob(pathname=path+"/**/*", recursive=True)
    for file in files:

        # get the relative path from the base path ("path") to the target
        # path ("file")
        p = Path(os.path.relpath(file, path))
       
        
        if os.path.isfile(file):
            # print(file)
            
            dir_path = os.path.dirname(file)
            folder_paths.append(file)

            dir_name = os.path.basename(dir_path)
            sub_folder_names.append(dir_name)

            file_name = os.path.basename(file)
            file_names.append(file_name)

            file_size = os.path.getsize(file)
            file_sizes.append(file_size)

            file_extension = os.path.splitext(file_name)[1]
            file_extenstions.append(file_extension)

            num_files_folder.append(0)
            
            is_folder.append(False)

            depth_count.append(len(p.parents)-1)
            
        else:
            dir_name = os.path.basename(file)
            sub_folder_names.append(dir_name)
            
            file_names.append("N/A")
            file_size = os.path.getsize(0)
            file_sizes.append(file_size)

            file_extenstions.append("N/A")

            f = os.listdir(file)
            num_files = len(f)
            num_files_folder.append(num_files)

            folder_paths.append(file)
            is_folder.append(True)

            depth_count.append(len(p.parents)-1)

        
    df = pd.DataFrame({
        'Path':folder_paths,
        'Folder Name':sub_folder_names,
        'Is Folder?': is_folder,
        'File Name':file_names,
        'File Size (Bytes)': file_sizes,
        'File Extensions': file_extenstions,
        'Number of Files in Folder': num_files_folder,
        'Depth': depth_count
        }   
    )

    return df

# %%
get_folder_overview(path)
# Out:
#                                         Path  Folder Name  Is Folder?  \
# 0   ../folder_structure_view.py               ..           False
# 1   ../__init__.py                            ..           False
# 2   ../__pycache__                            __pycache__  True
# 3   ../README.md                              ..           False
# 4   ../setup.py                               ..           False
# 5   ../notebooks                              notebooks    True
# 6   ../clone.py                               ..           False
# 7   ../__pycache__/copy.cpython-310.pyc       __pycache__  False
# 8   ../notebooks/batch_file_overwrite.ipynb   notebooks    False
# 9   ../notebooks/requirements.txt             notebooks    False
# 10  ../notebooks/folder_structure_view.ipynb  notebooks    False
# 11  ../notebooks/copy_num_folders.ipynb       notebooks    False
# 12  ../notebooks/copy_folders.ipynb           notebooks    False
#
#                       File Name  File Size (Bytes) File Extensions  \
# 0   folder_structure_view.py     2151               .py
# 1   __init__.py                  353                .py
# 2   N/A                          0                  N/A
# 3   README.md                    1114               .md
# 4   setup.py                     527                .py
# 5   N/A                          0                  N/A
# 6   clone.py                     2744               .py
# 7   copy.cpython-310.pyc         647                .pyc
# 8   batch_file_overwrite.ipynb   1503               .ipynb
# 9   requirements.txt             13                 .txt
# 10  folder_structure_view.ipynb  8476               .ipynb
# 11  copy_num_folders.ipynb       1819               .ipynb
# 12  copy_folders.ipynb           1157               .ipynb
#
#     Number of Files in Folder  Depth
# 0   0                          0
# 1   0                          0
# 2   1                          0
# 3   0                          0
# 4   0                          0
# 5   5                          0
# 6   0                          0
# 7   0                          1
# 8   0                          1
# 9   0                          1
# 10  0                          1
# 11  0                          1
# 12  0                          1
